# %% [markdown]
# # 사전 세팅

# %%
# 구글드라이브 연동
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

# 구글 드라이브 파일 확인
# !ls '/gdrive/My Drive/likelion_CoronaCosumePattern_project1/data/'

# 반복되는 드라이브 경로 변수화
drive_path = '/gdrive/My Drive/likelion_CoronaCosumePattern_project1/data/'
# Out:
# Mounted at /gdrive
#  신한카드_코로나19_카드이용건수
# '서울시 코로나19 확진자 현황.csv'
#  신한카드_코로나19_카드이용건수.xlsx
# 'Copy of South Korea.csv'
#  covid-19-data-master
# ' 한국문화관광연구원_소비자동향지수 현황(지출항목별 CSI).csv'
# '한국문화관광연구원_소비자동향지수 전망(지출항목별 CSI).csv'
# '한국문화관광연구원_문화체육관광 소비자물가지수.csv'
#  서울특별시_소비자_물가지수.txt

# %%
# 한글 폰트 적용
# !apt -qq -y install fonts-nanum
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randn
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 사용 데이터
#  한국문화관광연구원_소비자동향지수 현황(지출항목별 CSI)
#
#  한국문화관광연구원_소비자동향지수 전망(지출항목별 CSI)
#
#  한국문화관광연구원_문화체육관광 소비자물가지수

# %% [markdown]
# ##1. 한국문화관광연구원_소비자동향지수 현황(지출항목별 CSI)

# %%
temp_consumer_df = pd.read_csv('/gdrive/MyDrive/likelion_CoronaCosumePattern_project1/data/ 한국문화관광연구원_소비자동향지수 현황(지출항목별 CSI).csv', encoding='utf-16', delimiter='\t', index_col='세부항목')
display(temp_consumer_df.info())
display(temp_consumer_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 전체 to 600만원 이상
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   분류          253 non-null    object
#  1   항목          253 non-null    object
#  2   2020년 04분기  240 non-null    float64
#  3   2020년 03분기  239 non-null    float64
#  4   2020년 02분기  238 non-null    float64
#  5   2020년 01분기  240 non-null    float64
#  6   2019년 04분기  240 non-null    float64
#  7   2019년 03분기  240 non-null    float64
#  8   2019년 02분기  240 non-null    float64
#  9   2019년 01분기  240 non-null    float64
#  10  2018년 04분기  240 non-null    float64
#  11  2018년 03분기  240 non-null    float64
#  12  2018년 02분기  240 non-null    float64
#  13  2018년 01분기  240 non-null    float64
#  14  2017년 04분기  240 non-null    float64
#  15  2017년 03분기  240 non-null    float64
#  16  2017년 02분기  208 non-null    float64
#  17  2017년 01분기  208 non-null    float64
#  18  2016년 04분기  208 non-null    float64
#  19  2016년 03분기  208 non-null    float64
#  20  2016년 02분기  208 non-null    float64
#  21  2016년 01분기  208 non-null    float64
#  22  2015년 04분기  208 non-null    float64
#  23  2015년 03분기  208 non-null    float64
#  24  2015년 02분기  208 non-null    float64
#  25  2015년 01분기  208 non-null    float64
#  26  2014년 04분기  195 non-null    float64
#  27  2014년 03분기  195 non-null    float64
#  28  2014년 02분기  195 non-null    float64
#  29  2014년 01분기  195 non-null    float64
#  30  2013년 04분기  195 non-null    float64
#  31  2013년 03분기  195 non-null    float64
#  32  2013년 02분기  165 non-null    float64
# dtypes: float64(31), object(2)
# memory usage: 67.2+ KB
# None
#               분류     항목  2020년 04분기  ...  2013년 04분기  2013년 03분기  2013년 02분기
# 세부항목                                 ...
# 전체    오프라인 문화생활비     전체        66.4  ...        96.1        98.6       100.7
# 20대   오프라인 문화생활비  가구주연령        67.5  ...        98.3        91.8        99.9
# 30대   오프라인 문화생활비  가구주연령        57.5  ...        91.4        93.2        91.5
# 40대   오프라인 문화생활비  가구주연령        61.0  ...        89.6        92.8        89.9
# 50대   오프라인 문화생활비  가구주연령        66.4  ...        90.4        93.7        88.8
#
# [5 rows x 33 columns]

# %% [markdown]
# ### 1-1 각 항목 별로 분류
# *가구주연령 : family_age_df
#
# *가구원 수 : family_num_df
#
# *월평균 가구 소득 : family_income_df
#
# *세부항목 : 오프라인 비용, 해외 여행비, 온라인 비용, 오락용품 구입비

# %%
# 가구주 연령별
family_age_df = temp_consumer_df[temp_consumer_df['항목'] == '가구주연령']  # 가구주 연령으로 분류

family_age_off_df = family_age_df[family_age_df['분류'] == '오프라인 문화생활비'] # 가구주 연령 중 오프라인 문화생활비만 추출
family_age_off_df = family_age_off_df.iloc[0:, 3:14]
display(family_age_off_df)

family_age_off_trip_df = family_age_df[family_age_df['분류'] == '해외 여행비'] # 가구주 연령 중 해외 여행비만 추출
family_age_off_trip_df = family_age_off_trip_df.iloc[0:, 3:14]
display(family_age_off_trip_df)

family_age_on_df = family_age_df[family_age_df['분류'] == '온라인 문화생활비']  # 가구주 연령 중  온라인 문화생활비만 추출
family_age_on_df = family_age_on_df.iloc[0:, 3:14]
display(family_age_on_df)

family_age_on_play_df = family_age_df[family_age_df['분류'] == '오락용품 구입비']  # 가구주 연령 중  오락용품 구입비만 추출
family_age_on_play_df = family_age_on_play_df.iloc[0:, 3:14]
display(family_age_on_play_df)


# 가구원 수
family_num_df = temp_consumer_df[temp_consumer_df['항목'] == '가구원 수']

family_num_off_df = family_num_df[family_num_df['분류'] == '오프라인 문화생활비'] # 가구원 수 중 오프라인 문화생활비만 추출
family_num_off_df = family_num_off_df.iloc[0:, 3:14]
display(family_num_off_df)

family_num_off_trip_df = family_num_df[family_num_df['분류'] == '해외 여행비'] # 가구원 수 중 해외 여행비만 추출
family_num_off_trip_df = family_num_off_trip_df.iloc[0:, 3:14]
display(family_num_off_trip_df)

family_num_on_df = family_num_df[family_num_df['분류'] == '온라인 문화생활비']  # 가구원 수 중 온라인 문화생활비만 추출
family_num_on_df = family_num_on_df.iloc[0:, 3:14]
display(family_num_on_df)

family_num_on_play_df = family_num_df[family_num_df['분류'] == '오락용품 구입비']  # 가구원 수 중 오락용품 구입비만 추출
family_num_on_play_df = family_num_on_play_df.iloc[0:, 3:14]
display(family_num_on_play_df)


# 월평균 가구 소득
family_income_df = temp_consumer_df[temp_consumer_df['항목'] == '월평균 가구 소득']
family_income_df.fillna(method='ffill', inplace=True)

family_income_off_df = family_income_df[family_income_df['분류'] == '오프라인 문화생활비'] # 월평균 가구 소득중 오프라인 문화생활비만 추출
family_income_off_df = family_income_off_df.iloc[0:, 3:14]
display(family_income_off_df)

family_income_off_trip_df = family_income_df[family_income_df['분류'] == '해외 여행비'] # 월평균 가구 소득중 해외 여행비만 추출
family_income_off_trip_df = family_income_off_trip_df.iloc[0:, 3:14]
display(family_income_off_trip_df)

family_income_on_df = family_income_df[family_income_df['분류'] == '온라인 문화생활비']  # 월평균 가구 소득중  온라인 문화생활비만 추출
family_income_on_df = family_income_on_df.iloc[0:, 3:14]
display(family_income_on_df)

family_income_on_play_df = family_income_df[family_income_df['분류'] == '오락용품 구입비']  # 월평균 가구 소득중  오락용품 구입비만 추출
family_income_on_play_df = family_income_on_play_df.iloc[0:, 3:14]
display(family_income_on_play_df)
# Out:
#         2020년 03분기  2020년 02분기  2020년 01분기  ...  2018년 03분기  2018년 02분기  2018년 01분기
# 세부항목                                        ...
# 20대           63.8        56.8        55.8  ...       100.2       102.4       100.5
# 30대           60.8        61.4        57.2  ...        96.0        97.4        86.4
# 40대           64.9        59.9        53.2  ...        98.5        96.3        90.2
# 50대           70.8        65.7        63.4  ...        97.7        93.8        92.5
# 60대 이상        88.2        88.7        86.1  ...        97.1        95.7        94.9
#
# [5 rows x 11 columns]
#         2020년 03분기  2020년 02분기  2020년 01분기  ...  2018년 03분기  2018년 02분기  2018년 01분기
# 세부항목                                        ...
# 20대           94.2        83.9        83.2  ...       105.2       104.7       101.8
# 30대           85.4        79.3        78.8  ...       103.2       102.8       102.4
# 40대           89.7        84.9        76.7  ...       102.7       102.3       101.4
# 50대           90.5        86.0        79.1  ...       103.1       101.8       103.9
# 60대 이상        94.8        94.4        91.9  ...        99.6       105.7        98.7
#
# [5 rows x 11 columns]
#         2020년 03분기  2020년 02분기  2020년 01분기  ...  2018년 03분기  2018년 02분기  2018년 01분기
# 세부항목                                        ...
# 20대          114.1         NaN       116.5  ...       105.3       107.6       108.3
# 30대          117.4       113.9       104.4  ...       102.1       101.7        99.5
# 40대          115.5       110.9       108.0  ...       102.0       102.2       103.8
# 50대          107.2       107.9       100.4  ...        99.6       100.4       100.0
# 60대 이상        99.8        99.5        97.6  ...        99.0       100.7       100.5
#
# [5 rows x 11 columns]
#         2020년 03분기  2020년 02분기  2020년 01분기  ...  2018년 03분기  2018년 02분기  2018년 01분기
# 세부항목                                        ...
# 20대          104.3        99.4        97.1  ...       100.5        99.1       100.0
# 30대          114.4       111.5       105.7  ...       104.5       109.6       106.9
# 40대          105.8       107.3       103.2  ...        99.3       104.6        99.4
# 50대          100.1       100.4        96.8  ...        98.2        98.9        98.1
# 60대 이상        98.3       101.6        99.0  ...        99.8       101.8        99.8
#
# [5 rows x 11 columns]
#           2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                              ...
# 1인 가구           75.8        71.1  ...        98.7        96.0
# 2-3인 가구         72.0        69.5  ...        94.4        90.4
# 4인 이상 가구        61.6        59.4  ...        96.8        90.2
#
# [3 rows x 11 columns]
#           2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                              ...
# 1인 가구           92.2        88.3  ...       100.6        99.9
# 2-3인 가구         91.5        86.0  ...       103.8       102.0
# 4인 이상 가구        86.9        83.9  ...       104.7       103.5
#
# [3 rows x 11 columns]
#           2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                              ...
# 1인 가구          111.1       109.8  ...       102.6       103.6
# 2-3인 가구        106.1       107.4  ...       101.0       100.9
# 4인 이상 가구       117.0       111.4  ...       102.4       101.0
#
# [3 rows x 11 columns]
#           2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                              ...
# 1인 가구          100.1       101.5  ...        99.1        99.7
# 2-3인 가구        104.2       105.3  ...       103.2       100.8
# 4인 이상 가구       108.3       105.4  ...       106.7       101.0
#
# [3 rows x 11 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#                 2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                                    ...
# 99만원 이하               87.8        84.7  ...        96.6        99.3
# 100만원-199만원 이하        79.4        76.0  ...        96.5        91.4
# 200만원-299만원 이하        70.2        69.5  ...        98.4        94.7
# 300만원-399만원 이하        68.7        64.3  ...        94.4        88.8
# 400만원-499만원 이하        62.5        63.9  ...        96.4        90.3
# 500만원 이상              62.5        63.9  ...        96.4        90.3
# 500만원-599만원 이하        61.2        56.9  ...        91.2        88.6
# 600만원 이상              64.6        56.0  ...        98.6        91.8
#
# [8 rows x 11 columns]
#                 2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                                    ...
# 99만원 이하               97.7        95.2  ...        99.4        97.5
# 100만원-199만원 이하        90.6        89.2  ...       102.2        97.3
# 200만원-299만원 이하        88.2        90.3  ...       102.3       100.5
# 300만원-399만원 이하        87.9        87.2  ...       100.9        97.5
# 400만원-499만원 이하        88.6        85.2  ...       100.7       100.9
# 500만원-599만원 이하        90.5        81.8  ...       104.7       108.2
# 600만원 이상              90.4        74.8  ...       108.8       108.4
#
# [7 rows x 11 columns]
#                 2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                                    ...
# 99만원 이하              105.7       103.6  ...       101.7       101.0
# 100만원-199만원 이하       100.2       104.7  ...       100.6       103.0
# 200만원-299만원 이하       106.0       105.0  ...       102.4       102.3
# 300만원-399만원 이하       108.4       108.8  ...       100.4       103.0
# 400만원-499만원 이하       115.6       111.9  ...       102.5        98.6
# 500만원 이상             115.6       111.9  ...       102.5        98.6
# 500만원-599만원 이하       117.5       109.2  ...       101.7        99.2
# 600만원 이상             115.8       119.1  ...       102.8       103.4
#
# [8 rows x 11 columns]
#                 2020년 03분기  2020년 02분기  ...  2018년 02분기  2018년 01분기
# 세부항목                                    ...
# 99만원 이하               99.4        99.2  ...        99.5        99.1
# 100만원-199만원 이하        96.5       100.9  ...       100.7        99.7
# 200만원-299만원 이하       100.8       103.1  ...       101.6       100.1
# 300만원-399만원 이하       106.0       103.6  ...       103.4       102.8
# 400만원-499만원 이하       107.1       108.9  ...       106.4        98.4
# 500만원 이상             107.1       108.9  ...       106.4        98.4
# 500만원-599만원 이하       108.9       108.6  ...       104.0       101.0
# 600만원 이상             107.8       107.0  ...       103.8       101.0
#
# [8 rows x 11 columns]

# %% [markdown]
# ### 1-2 각 항목 별로 시각화
# *가구주연령 : family_age_df
#
# *가구원 수 : family_num_df
#
# *월평균 가구 소득 : family_income_df
#
# *세부항목 : 오프라인 비용, 해외 여행비, 온라인 비용, 오락용품 구입비

# %%
import seaborn as sns
# 시각화 여러개 나오게 하기

figure, ((ax1,ax2,ax3, ax4), (ax5,ax6,ax7,ax8) , (ax9,ax10,ax11,ax12)) = plt.subplots(nrows = 3, ncols =4 )
figure.set_size_inches(70,30)

# 가구주연령별
ax1.set_title('가구주연령별(오프라인비용)', fontsize=20)
sns.lineplot(data = family_age_off_df.T, marker='o', linewidth=3, ax= ax1)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.legend(fontsize=12, loc='best')

ax2.set_title('가구주연령별(해외 여행비)', fontsize=20)
sns.lineplot(data = family_age_off_trip_df.T, marker='o', linewidth=3, ax= ax2)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax3.set_title('가구주연령별(온라인비용)', fontsize=20)
sns.lineplot(data = family_age_on_df.T, marker='o', linewidth=3, ax= ax3)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax4.set_title('가구주연령별(오락용품 구입비)', fontsize=20)
sns.lineplot(data = family_age_on_play_df.T, marker='o', linewidth=3, ax= ax4)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

# 가구원 수별

ax5.set_title('가구원 수(오프라인비용)', fontsize=20)
sns.lineplot(data = family_num_off_df.T, marker='o', linewidth=3, ax= ax5)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax6.set_title('가구원 수(해외 여행비)', fontsize=20)
sns.lineplot(data = family_num_off_trip_df.T, marker='o', linewidth=3, ax= ax6)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax7.set_title('가구원 수(온라인비용)', fontsize=20)
sns.lineplot(data = family_num_on_df.T, marker='o', linewidth=3, ax= ax7)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax8.set_title('가구원 수(오락용품 구입비)', fontsize=20)
sns.lineplot(data = family_num_on_play_df.T, marker='o', linewidth=3, ax= ax8)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

# 월평균 가구 소득

ax9.set_title('월평균 가구 소득(오프라인비용)', fontsize=20)
sns.lineplot(data = family_income_off_df.T, marker='o', linewidth=3, ax= ax9)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax10.set_title('월평균 가구 소득(해외 여행비)', fontsize=20)
sns.lineplot(data = family_income_off_trip_df.T, marker='o', linewidth=3, ax= ax10)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax11.set_title('월평균 가구 소득(온라인비용)', fontsize=20)
sns.lineplot(data = family_income_on_df.T, marker='o', linewidth=3, ax= ax11)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)

ax12.set_title('월평균 가구 소득(오락용품 구입비)', fontsize=20)
sns.lineplot(data = family_income_on_play_df.T, marker='o', linewidth=3, ax= ax12)
plt.ylabel('Consume cost', fontsize=14)
plt.xlabel('Date', fontsize=14)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 2. 한국문화관광연구원_소비자동향지수 전망(지출항목별 CSI)

# %%
future_consumer_df = pd.read_csv('/gdrive/MyDrive/likelion_CoronaCosumePattern_project1/data/한국문화관광연구원_소비자동향지수 전망(지출항목별 CSI).csv', encoding='utf-16', delimiter='\t')
display(temp_consumer_df.info())
display(temp_consumer_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   분류          253 non-null    object
#  1   항목          253 non-null    object
#  2   세부항목        253 non-null    object
#  3   2021년 01분기  240 non-null    float64
#  4   2020년 04분기  239 non-null    float64
#  5   2020년 03분기  239 non-null    float64
#  6   2020년 02분기  240 non-null    float64
#  7   2020년 01분기  240 non-null    float64
#  8   2019년 04분기  240 non-null    float64
#  9   2019년 03분기  240 non-null    float64
#  10  2019년 02분기  240 non-null    float64
#  11  2019년 01분기  240 non-null    float64
#  12  2018년 04분기  240 non-null    float64
#  13  2018년 03분기  240 non-null    float64
#  14  2018년 02분기  240 non-null    float64
#  15  2018년 01분기  240 non-null    float64
#  16  2017년 04분기  240 non-null    float64
#  17  2017년 03분기  208 non-null    float64
#  18  2017년 02분기  208 non-null    float64
#  19  2017년 01분기  208 non-null    float64
#  20  2016년 04분기  208 non-null    float64
#  21  2016년 03분기  208 non-null    float64
#  22  2016년 02분기  208 non-null    float64
#  23  2016년 01분기  208 non-null    float64
#  24  2015년 04분기  208 non-null    float64
#  25  2015년 03분기  208 non-null    float64
#  26  2015년 02분기  208 non-null    float64
#  27  2015년 01분기  195 non-null    float64
#  28  2014년 04분기  195 non-null    float64
#  29  2014년 03분기  195 non-null    float64
#  30  2014년 02분기  195 non-null    float64
#  31  2014년 01분기  195 non-null    float64
#  32  2013년 04분기  195 non-null    float64
#  33  2013년 03분기  165 non-null    float64
#  34  2013년 02분기  0 non-null      float64
# dtypes: float64(32), object(3)
# memory usage: 69.3+ KB
# None
#            분류     항목 세부항목  ...  2013년 04분기  2013년 03분기  2013년 02분기
# 0  오프라인 문화생활비     전체   전체  ...       104.1       104.5         NaN
# 1  오프라인 문화생활비  가구주연령  20대  ...       108.2       107.4         NaN
# 2  오프라인 문화생활비  가구주연령  30대  ...       104.4       110.2         NaN
# 3  오프라인 문화생활비  가구주연령  40대  ...       102.5       104.0         NaN
# 4  오프라인 문화생활비  가구주연령  50대  ...       103.7       100.6         NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 2-1 각 항목 별로 분류
# *가구주연령 : future_family_age_df
#
# *가구원 수 : future_family_num_df
#
# *월평균 가구 소득 : future_family_income_df

# %%
future_family_age_df = future_consumer_df[future_consumer_df['항목'] == '가구주연령']                           
future_family_num_df = future_consumer_df[future_consumer_df['항목'] == '가구원 수']
future_family_income_df = future_consumer_df[future_consumer_df['항목'] == '월평균 가구 소득']

display(future_family_age_df)
display(future_family_num_df)
display(future_family_income_df)
# Out:
#              분류     항목    세부항목  ...  2013년 04분기  2013년 03분기  2013년 02분기
# 1    오프라인 문화생활비  가구주연령     20대  ...       108.2       107.4         NaN
# 2    오프라인 문화생활비  가구주연령     30대  ...       104.4       110.2         NaN
# 3    오프라인 문화생활비  가구주연령     40대  ...       102.5       104.0         NaN
# 4    오프라인 문화생활비  가구주연령     50대  ...       103.7       100.6         NaN
# 5    오프라인 문화생활비  가구주연령  60대 이상  ...       104.8       103.3         NaN
# ..          ...    ...     ...  ...         ...         ...         ...
# 237     스포츠 학원비  가구주연령     20대  ...        99.2         NaN         NaN
# 238     스포츠 학원비  가구주연령     30대  ...        98.7         NaN         NaN
# 239     스포츠 학원비  가구주연령     40대  ...        97.2         NaN         NaN
# 240     스포츠 학원비  가구주연령     50대  ...        96.9         NaN         NaN
# 241     스포츠 학원비  가구주연령  60대 이상  ...       100.2         NaN         NaN
#
# [75 rows x 35 columns]
#              분류     항목      세부항목  ...  2013년 04분기  2013년 03분기  2013년 02분기
# 6    오프라인 문화생활비  가구원 수     1인 가구  ...       107.4       101.1         NaN
# 7    오프라인 문화생활비  가구원 수   2-3인 가구  ...       103.9       106.0         NaN
# 8    오프라인 문화생활비  가구원 수  4인 이상 가구  ...       101.7       105.0         NaN
# 23    온라인 문화생활비  가구원 수     1인 가구  ...       100.4       100.4         NaN
# 24    온라인 문화생활비  가구원 수   2-3인 가구  ...       101.1       100.8         NaN
# 25    온라인 문화생활비  가구원 수  4인 이상 가구  ...        99.8        99.0         NaN
# 40    스포츠시설 이용료  가구원 수     1인 가구  ...       105.3       104.0         NaN
# 41    스포츠시설 이용료  가구원 수   2-3인 가구  ...       104.5       106.8         NaN
# 42    스포츠시설 이용료  가구원 수  4인 이상 가구  ...       103.1       102.8         NaN
# 57    스포츠기구 구입비  가구원 수     1인 가구  ...       103.9       103.5         NaN
# 58    스포츠기구 구입비  가구원 수   2-3인 가구  ...       101.4       105.8         NaN
# 59    스포츠기구 구입비  가구원 수  4인 이상 가구  ...        99.3       101.6         NaN
# 74    스포츠경기 관람료  가구원 수     1인 가구  ...        96.0         NaN         NaN
# 75    스포츠경기 관람료  가구원 수   2-3인 가구  ...        97.3         NaN         NaN
# 76    스포츠경기 관람료  가구원 수  4인 이상 가구  ...        95.5         NaN         NaN
# 91   아웃도어용품 구입비  가구원 수     1인 가구  ...       104.5       104.2         NaN
# 92   아웃도어용품 구입비  가구원 수   2-3인 가구  ...       102.2       106.4         NaN
# 93   아웃도어용품 구입비  가구원 수  4인 이상 가구  ...       103.5       105.3         NaN
# 108   미디어기기 구입비  가구원 수     1인 가구  ...       103.2        99.7         NaN
# 109   미디어기기 구입비  가구원 수   2-3인 가구  ...       102.5       100.4         NaN
# 110   미디어기기 구입비  가구원 수  4인 이상 가구  ...       100.7       100.8         NaN
# 125      관광·여행비  가구원 수     1인 가구  ...       105.6       123.3         NaN
# 126      관광·여행비  가구원 수   2-3인 가구  ...       106.0       123.6         NaN
# 127      관광·여행비  가구원 수  4인 이상 가구  ...       105.6       124.2         NaN
# 142      국내 여행비  가구원 수     1인 가구  ...         NaN         NaN         NaN
# 143      국내 여행비  가구원 수   2-3인 가구  ...         NaN         NaN         NaN
# 144      국내 여행비  가구원 수  4인 이상 가구  ...         NaN         NaN         NaN
# 158      해외 여행비  가구원 수     1인 가구  ...         NaN         NaN         NaN
# 159      해외 여행비  가구원 수   2-3인 가구  ...         NaN         NaN         NaN
# 160      해외 여행비  가구원 수  4인 이상 가구  ...         NaN         NaN         NaN
# 174      도서 구입비  가구원 수     1인 가구  ...       108.3       104.4         NaN
# 175      도서 구입비  가구원 수   2-3인 가구  ...       104.9       103.7         NaN
# 176      도서 구입비  가구원 수  4인 이상 가구  ...       106.3       106.8         NaN
# 191    오락용품 구입비  가구원 수     1인 가구  ...        95.7        98.4         NaN
# 192    오락용품 구입비  가구원 수   2-3인 가구  ...       100.0       100.2         NaN
# 193    오락용품 구입비  가구원 수  4인 이상 가구  ...        97.9        99.0         NaN
# 208    오락시설 이용료  가구원 수     1인 가구  ...        99.9        98.4         NaN
# 209    오락시설 이용료  가구원 수   2-3인 가구  ...        98.6        99.6         NaN
# 210    오락시설 이용료  가구원 수  4인 이상 가구  ...        94.9       101.6         NaN
# 225   음악·미술 학원비  가구원 수     1인 가구  ...        98.6       100.6         NaN
# 226   음악·미술 학원비  가구원 수   2-3인 가구  ...        99.6       100.2         NaN
# 227   음악·미술 학원비  가구원 수  4인 이상 가구  ...       102.1       103.3         NaN
# 242     스포츠 학원비  가구원 수     1인 가구  ...        98.2         NaN         NaN
# 243     스포츠 학원비  가구원 수   2-3인 가구  ...        98.6         NaN         NaN
# 244     스포츠 학원비  가구원 수  4인 이상 가구  ...        97.3         NaN         NaN
#
# [45 rows x 35 columns]
#              분류         항목            세부항목  ...  2013년 04분기  2013년 03분기  2013년 02분기
# 9    오프라인 문화생활비  월평균 가구 소득         99만원 이하  ...       100.3        99.4         NaN
# 10   오프라인 문화생활비  월평균 가구 소득  100만원-199만원 이하  ...       100.0       102.3         NaN
# 11   오프라인 문화생활비  월평균 가구 소득  200만원-299만원 이하  ...       102.4       103.0         NaN
# 12   오프라인 문화생활비  월평균 가구 소득  300만원-399만원 이하  ...       101.7       105.1         NaN
# 13   오프라인 문화생활비  월평균 가구 소득  400만원-499만원 이하  ...       106.5       103.4         NaN
# ..          ...        ...             ...  ...         ...         ...         ...
# 248     스포츠 학원비  월평균 가구 소득  300만원-399만원 이하  ...        98.4         NaN         NaN
# 249     스포츠 학원비  월평균 가구 소득  400만원-499만원 이하  ...        99.6         NaN         NaN
# 250     스포츠 학원비  월평균 가구 소득        500만원 이상  ...        97.7         NaN         NaN
# 251     스포츠 학원비  월평균 가구 소득  500만원-599만원 이하  ...         NaN         NaN         NaN
# 252     스포츠 학원비  월평균 가구 소득        600만원 이상  ...         NaN         NaN         NaN
#
# [118 rows x 35 columns]
